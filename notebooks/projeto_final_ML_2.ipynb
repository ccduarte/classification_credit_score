# %% [markdown]
# # Credit Score Classification
# ## Projeto final Machine Learning - MBA Data Science & Artificial Intelligence (4DTSR)
#  Kaggle: https://www.kaggle.com/datasets/parisrohan/credit-score-classification/data

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option("display.max_rows", None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.stats as stats
import statistics

import warnings
warnings.filterwarnings('ignore')

# %%
df_dict = pd.read_csv('./bases/dicionario_dados.csv', sep=';')
df_dict
# Out:
#                       column  \
# 0                         ID
# 1                Customer_ID
# 2                      Month
# 3                       Name
# 4                        Age
# 5                        SSN
# 6                 Occupation
# 7              Annual_Income
# 8      Monthly_Inhand_Salary
# 9          Num_Bank_Accounts
# 10           Num_Credit_Card
# 11             Interest_Rate
# 12               Num_of_Loan
# 13              Type_of_Loan
# 14       Delay_from_due_date
# 15    Num_of_Delayed_Payment
# 16      Changed_Credit_Limit
# 17      Num_Credit_Inquiries
# 18                Credit_Mix
# 19          Outstanding_Debt
# 20  Credit_Utilization_Ratio
# 21        Credit_History_Age
# 22     Payment_of_Min_Amount
# 23       Total_EMI_per_month
# 24   Amount_invested_monthly
# 25         Payment_Behaviour
# 26           Monthly_Balance
#
#                                             description_en  \
# 0                        unique identification of an entry
# 1                        unique identification of a person
# 2                                        month of the year
# 3                                         name of a person
# 4                                        age of the person
# 5                       social security number of a person
# 6                                 occupation of the person
# 7                              annual income of the person
# 8                          monthly base salary of a person
# 9                   number of bank accounts a person holds
# 10           number of other credit cards held by a person
# 11                            interest rate on credit card
# 12                     number of loans taken from the bank
# 13                         types of loan taken by a person
# 14    average number of days delayed from the payment date
# 15          average number of payments delayed by a person
# 16                  percentage change in credit card limit
# 17                         number of credit card inquiries
# 18                    classification of the mix of credits
# 19                      remaining debt to be paid (in USD)
# 20                        utilization ratio of credit card
# 21                     age of credit history of the person
# 22  whether only the minimum amount was paid by the person
# 23                           monthly EMI payments (in USD)
# 24        monthly amount invested by the customer (in USD)
# 25               payment behavior of the customer (in USD)
# 26         monthly balance amount of the customer (in USD)
#
#                                                   description_pt
# 0                             identificação única de uma entrada
# 1                              identificação única de uma pessoa
# 2                                                   o mês do ano
# 3                                             nome de uma pessoa
# 4                                                idade da pessoa
# 5                       número de segurança social de uma pessoa
# 6                                             ocupação da pessoa
# 7                                          renda anual da pessoa
# 8                                  salário base mensal da pessoa
# 9               número de contas bancárias que uma pessoa possui
# 10     número de outros cartões de crédito que uma pessoa possui
# 11                            taxa de juros no cartão de crédito
# 12                        número de empréstimos tomados do banco
# 13                   tipos de empréstimos tomados por uma pessoa
# 14  número médio de dias de atraso a partir da data de pagamento
# 15           número médio de pagamentos atrasados por uma pessoa
# 16         porcentagem de mudança no limite do cartão de crédito
# 17                                número de consultas de crédito
# 18                              classificação do mix de créditos
# 19                           dívida restante a ser paga (em USD)
# 20                       taxa de utilização do cartão de crédito
# 21                       idade do histórico de crédito da pessoa
# 22                    se apenas o valor mínimo foi pago (em USD)
# 23                  total mensal dos EMIs investidos pela pessoa
# 24                   valor mensal investido pela pessoa (em USD)
# 25                comportamento de pagamento do cliente (em USD)
# 26               saldo mensal médio da conta do cliente (em USD)

# %%
df_train = pd.read_csv('./bases/train.csv')

# %%
df_test = pd.read_csv('./bases/test.csv')

# %%
df_train.head(5)
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0      19114.12               1824.843                  3                4
# 1      19114.12                    NaN                  3                4
# 2      19114.12                    NaN                  3                4
# 3      19114.12                    NaN                  3                4
# 4      19114.12               1824.843                  3                4
#
#    Interest_Rate Num_of_Loan  \
# 0              3           4
# 1              3           4
# 2              3           4
# 3              3           4
# 4              3           4
#
#                                                           Type_of_Loan  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan
# 1  Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan
# 2  Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan
# 3  Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan
# 4  Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan
#
#    Delay_from_due_date Num_of_Delayed_Payment Changed_Credit_Limit  \
# 0                    3                      7                11.27
# 1                   -1                    NaN                11.27
# 2                    3                      7                    _
# 3                    5                      4                 6.27
# 4                    6                    NaN                11.27
#
#    Num_Credit_Inquiries Credit_Mix Outstanding_Debt  Credit_Utilization_Ratio  \
# 0                 4.000          _           809.98                    26.823
# 1                 4.000       Good           809.98                    31.945
# 2                 4.000       Good           809.98                    28.609
# 3                 4.000       Good           809.98                    31.378
# 4                 4.000       Good           809.98                    24.797
#
#       Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 0  22 Years and 1 Months                    No               49.575
# 1                    NaN                    No               49.575
# 2  22 Years and 3 Months                    No               49.575
# 3  22 Years and 4 Months                    No               49.575
# 4  22 Years and 5 Months                    No               49.575
#
#   Amount_invested_monthly                 Payment_Behaviour  \
# 0       80.41529543900253   High_spent_Small_value_payments
# 1      118.28022162236736    Low_spent_Large_value_payments
# 2         81.699521264648   Low_spent_Medium_value_payments
# 3       199.4580743910713    Low_spent_Small_value_payments
# 4      41.420153086217326  High_spent_Medium_value_payments
#
#       Monthly_Balance Credit_Score
# 0  312.49408867943663         Good
# 1  284.62916249607184         Good
# 2   331.2098628537912         Good
# 3  223.45130972736786         Good
# 4  341.48923103222177         Good
